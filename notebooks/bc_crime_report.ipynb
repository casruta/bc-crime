# %% [markdown]
# # Exploring the Crime Landscape in British Columbia
#
# **Author:** Kacper Ruta
# **Date:** March 2026
# **Data Sources:** Statistics Canada Tables 35-10-0063-01, 35-10-0177-01; BC Ministry of Public Safety Appendices F, G, H, I (2023)
#
# ---
#
# ## Executive Summary
#
# <!-- NOTE: The statistics below are hardcoded. Verify against current data when regenerating. -->
#
# This analysis examines four core questions about crime in British Columbia:
#
# 1. **Is crime rising?** BC's Crime Severity Index peaked in 1998 (166.9) and fell 46% to a trough in 2014 (90.2). Since then it has plateaued around 93–107, with a notable 7.4% drop in the latest year (2024). BC's overall crime rate remains 21% above the national average. <!-- Verify: CSI peak 166.9, trough 90.2, YoY drop 7.4%, gap 21% -->
#
# 2. **What kinds of crime are changing?** Property crime dominates (51% of total rate) but is declining — theft from vehicles fell by 772 per 100,000 over five years. Meanwhile, child exploitation offences (+82/100k) and shoplifting (+79/100k) are rising sharply. Violent crime's share is growing even as its absolute rate stabilizes. <!-- Verify: property share 51%, theft from vehicles -772, child exploitation +82, shoplifting +79 -->
#
# 3. **How effectively is crime being addressed?** Clearance rates vary dramatically by crime type — violent crime clearance exceeds 50% while property crime sits below 30%. Youth crime severity has diverged sharply from the adult trend, and COVID-19 reshaped crime patterns in ways still visible in 2024. <!-- Verify: violent clearance >50%, property clearance <30% -->
#
# 4. **Where is crime concentrated?** Vancouver (48,812 offences) and Surrey (41,275) account for the bulk of BC's crime volume. But per-capita rates tell a different story: interior CMAs like Chilliwack (11,352/100k) and Kamloops (10,546/100k) have twice the crime rate of Vancouver (5,438/100k) and Victoria (5,283/100k). <!-- Verify: Vancouver 48,812, Surrey 41,275, Chilliwack 11,352/100k, Kamloops 10,546/100k, Vancouver 5,438/100k, Victoria 5,283/100k -->

# %% [markdown]
# ---
#
# ## Setup

# %%
import sys
from pathlib import Path

# Add project root to path so we can import src modules
project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.analysis.theme import apply_theme
apply_theme()

CHARTS = project_root / "outputs" / "charts"

# %% [markdown]
# ---
#
# ## Section 1: Is Crime Rising in BC?
#
# The Crime Severity Index (CSI) is the gold standard for measuring crime trends. Unlike raw counts, it weights offences by their severity — a homicide counts far more than a petty theft. StatCan has published BC's CSI since 1998.

# %%
from src.analysis.q1_is_crime_rising import chart_bc_csi_trend
fig, narrative = chart_bc_csi_trend()
fig.show()
print(narrative)

# %% [markdown]
# The total CSI peaked at 166.9 in 1998 during the tail end of the 1990s crime wave, then entered a sustained decline — falling 46% to 90.2 by 2014. Since the 2014 trough, the CSI has risen modestly but remains well below its historical peak.
#
# Critically, the **violent CSI has risen more steeply** than the non-violent CSI since 2014. This signals that while overall crime volume is flat, the *composition* is shifting toward more serious offences.

# %%
from src.analysis.q1_is_crime_rising import chart_provincial_comparison
fig, narrative = chart_provincial_comparison()
fig.show()
print(narrative)

# %% [markdown]
# Compared to other provinces, BC's crime rate is **21% above the national average** but significantly lower than the Prairie provinces. Saskatchewan consistently has the highest rate — roughly double that of Ontario. All provinces show the same broad pattern: a peak around 2003, a decline to 2014, and a plateau or slight rise since.

# %%
from src.analysis.q1_is_crime_rising import chart_yoy_change_by_province, chart_bc_yoy_trend
fig, narrative = chart_yoy_change_by_province()
fig.show()
print(narrative)

# %%
fig, narrative = chart_bc_yoy_trend()
fig.show()
print(narrative)

# %% [markdown]
# The latest year (2023→2024) saw BC's crime rate **fall 7.4%** — the second-largest decline among comparison provinces after Alberta (-8.5%). Over the full time series, BC has had 18 years of declining rates vs 8 years of increases.

# %%
from src.analysis.q1_is_crime_rising import chart_indexed_provincial_growth, chart_violent_nonviolent_gap, chart_bc_canada_gap, chart_csi_contribution

fig, narrative = chart_indexed_provincial_growth()
fig.show()
print(narrative)

# %%
fig, narrative = chart_violent_nonviolent_gap()
fig.show()
print(narrative)

# %%
fig, narrative = chart_bc_canada_gap()
fig.show()
print(narrative)

# %%
fig, narrative = chart_csi_contribution()
fig.show()
print(narrative)

# %% [markdown]
# ---
#
# ## Section 2: What Kinds of Crime Are Changing?
#
# Understanding *which* crimes are rising or falling is essential for policy. A drop in property crime can mask a rise in violent crime if you only look at totals.

# %%
from src.analysis.q2_what_kinds import chart_stacked_area
fig, narrative = chart_stacked_area()
fig.show()
print(narrative)

# %% [markdown]
# Property crime remains the dominant category (51% of total rate) but has been **declining steadily** since the early 2000s. Violent crime's share has grown proportionally even though its absolute rate has been relatively flat.

# %%
from src.analysis.q2_what_kinds import chart_heatmap
fig, narrative = chart_heatmap()
fig.show()
print(narrative)

# %%
from src.analysis.q2_what_kinds import chart_top_changes
fig, narrative = chart_top_changes()
fig.show()
print(narrative)

# %% [markdown]
# The biggest absolute rate declines over 5 years:
# - **Theft from vehicles** (-772 per 100,000) — the single largest drop
# - **Breaking and entering** (-270)
# - **Theft $5,000 or under** (-221)
# - **Disturb the peace** (-165)
#
# The biggest absolute increases:
# - **Child pornography offences** (+82) — a concerning trend
# - **Shoplifting** (+79) — likely reflecting both actual increases and changes in reporting

# %%
from src.analysis.q2_what_kinds import chart_slope, find_fastest_changing
fig, narrative = chart_slope()
fig.show()

rising, declining = find_fastest_changing()
print("\nTop 5 fastest-rising violations (5-year % change):")
for _, r in rising.iterrows():
    print(f"  {r['violation'].split(' [')[0]}: {r['pct_change']:+.1f}%")
print("\nTop 5 fastest-declining violations:")
for _, r in declining.iterrows():
    print(f"  {r['violation'].split(' [')[0]}: {r['pct_change']:+.1f}%")

# %%
from src.analysis.q2_what_kinds import chart_composition_shares, chart_category_cagr
fig, narrative = chart_composition_shares()
fig.show()
print(narrative)

# %%
fig, narrative = chart_category_cagr()
fig.show()
print(narrative)

# %%
from src.analysis.q2_what_kinds import chart_specific_violation_trends, chart_rising_violations_spotlight
fig, narrative = chart_specific_violation_trends()
fig.show()
print(narrative)

# %%
fig, narrative = chart_rising_violations_spotlight()
fig.show()
print(narrative)

# %% [markdown]
# ---
#
# ## Section 3: How Effectively Is Crime Being Addressed?
#
# This section examines justice system effectiveness using clearance rates, youth vs adult crime severity, policing model comparisons, COVID-19 impact, and unfounded incident rates. These metrics go beyond "how much crime" to ask "how well is the system responding?"

# %%
from src.analysis.q3_justice import chart_clearance_rate_trends, chart_clearance_by_violation
fig, narrative = chart_clearance_rate_trends()
fig.show()
print(narrative)

# %%
fig, narrative = chart_clearance_by_violation()
fig.show()
print(narrative)

# %%
from src.analysis.q3_justice import chart_youth_vs_adult_csi, chart_rcmp_vs_municipal
fig, narrative = chart_youth_vs_adult_csi()
fig.show()
print(narrative)

# %% [markdown]
# Youth crime severity has diverged sharply from the adult trend — while the overall CSI has stabilized or risen since 2014, the youth CSI has continued to decline. This divergence suggests youth-specific interventions or demographic shifts are at work.
#
# The policing model comparison shows how crime volumes differ between independent municipal forces, RCMP municipal detachments, and RCMP provincial detachments.

# %%
fig, narrative = chart_rcmp_vs_municipal()
fig.show()
print(narrative)

# %%
from src.analysis.q3_justice import chart_covid_impact, chart_unfounded_rates
fig, narrative = chart_covid_impact()
fig.show()
print(narrative)

# %%
fig, narrative = chart_unfounded_rates()
fig.show()
print(narrative)

# %% [markdown]
# ### The Reporting Gap: Could Underreporting Explain the Decline?
#
# The apparent decline in crime rates may partly reflect less crime being *reported* rather than less crime occurring. Statistics Canada's General Social Survey on Canadians' Safety (2019) found that only **29% of criminal victimizations** were reported to police. Reporting rates vary dramatically: property crime at roughly 35%, violent crime at 24%, sexual assault at just 6%.
#
# Three proxy indicators test whether underreporting drives the observed decline: unfounded rate trends, clearance method shifts (charge vs "cleared otherwise"), and differential decline rates across categories with different reporting rates.

# %%
from src.analysis.q3_justice import chart_underreporting_proxies
fig, narrative = chart_underreporting_proxies()
fig.show()
print(narrative)

# %% [markdown]
# **Assessment.** The proxy data partly supports the underreporting hypothesis — but with a critical exception. Property crime, which has a *higher* reporting rate and is therefore less sensitive to reporting changes, declined more steeply than violent crime. That is the *opposite* of what a reporting-driven decline would produce. The most defensible conclusion: underreporting likely contributes to some of the property crime decline (particularly low-value theft) but cannot explain the violent crime trends.

# %% [markdown]
# ### Policing Costs and Cost-Effectiveness
#
# BC's policing bill grew steadily — but did the spending produce results? Statistics Canada's police administration survey (Table 35-10-0076-01) provides expenditure, staffing, and workload data from 1986 to 2023.

# %%
from src.analysis.q3_costs import chart_bc_expenditure_trend
fig, narrative = chart_bc_expenditure_trend()
fig.show()
print(narrative)

# %%
from src.analysis.q3_costs import chart_per_capita_comparison
fig, narrative = chart_per_capita_comparison()
fig.show()
print(narrative)

# %%
from src.analysis.q3_costs import chart_csi_vs_expenditure
fig, narrative = chart_csi_vs_expenditure()
fig.show()
print(narrative)

# %% [markdown]
# Spending rose while crime severity fell — then kept rising as crime plateaued. This divergence raises cost-effectiveness questions: are we paying more for the same outcomes, or are rising costs funding capabilities (mental health response, technology, training) not captured by traditional crime metrics?

# %%
from src.analysis.q3_costs import chart_expenditure_breakdown
fig, narrative = chart_expenditure_breakdown()
fig.show()
print(narrative)

# %% [markdown]
# Staffing levels add another dimension. The number of police officers per 100,000 measures whether the force kept pace with a growing province.

# %%
from src.analysis.q3_costs import chart_staffing_trend
fig, narrative = chart_staffing_trend()
fig.show()
print(narrative)

# %% [markdown]
# Combining staffing with crime data yields a workload measure: how many Criminal Code incidents does each officer handle? Overlaid with the Crime Severity Index, this reveals whether declining crime translated into reduced workload or whether other demands absorbed the capacity.

# %%
from src.analysis.q3_costs import chart_crimes_per_officer
fig, narrative = chart_crimes_per_officer()
fig.show()
print(narrative)

# %% [markdown]
# ---
#
# ## Section 4: Where Is Crime Happening?
#
# Geographic analysis at two levels: police jurisdiction (BC Gov data, 2014–2023) and Census Metropolitan Area (StatCan national table).

# %%
from src.analysis.q4_geography import chart_top_jurisdictions
fig, narrative = chart_top_jurisdictions()
fig.show()
print(narrative)

# %%
from src.analysis.q4_geography import chart_jurisdiction_trends
fig, narrative = chart_jurisdiction_trends()
fig.show()
print(narrative)

# %%
from src.analysis.q4_geography import chart_total_vs_violent
fig, narrative = chart_total_vs_violent()
fig.show()
print(narrative)

# %%
from src.analysis.q4_geography import chart_cma_comparison
fig, narrative = chart_cma_comparison()
fig.show()
print(narrative)

# %% [markdown]
# The CMA comparison reveals a striking urban-rural divide: **interior and smaller CMAs have dramatically higher per-capita crime rates** than the large coastal metros. Chilliwack (11,352/100k) and Kamloops (10,546/100k) have roughly twice the rate of Vancouver (5,438/100k) and Victoria (5,283/100k). This pattern likely reflects differences in economic conditions, homelessness, substance use, and policing models.

# %% [markdown]
# ---
#
# ## Methodology Notes
#
# ### Data Sources
#
# | Source | Table | Description | Coverage |
# |--------|-------|-------------|----------|
# | Statistics Canada | 35-10-0063-01 | Crime Severity Index by police service, BC | 1998–2024 |
# | Statistics Canada | 35-10-0177-01 | Incident-based crime stats by province/CMA | 1998–2024 |
# | Statistics Canada | 18-10-0005-01 | Consumer Price Index, annual | 1914–2024 |
# | BC Gov | Appendix F | Crime Statistics in BC, 2023 | 2022–2023 |
# | BC Gov | Appendix G | BC Crime Trends | 2014–2023 |
# | BC Gov | Appendix I | BC Jurisdiction Crime Trends | 2014–2023 |
#
# ### Key Metrics
#
# - **Crime Severity Index (CSI):** Developed by StatCan, assigns a weight to each offence based on average sentences. Higher = more serious crime mix. Base year: 2006.
# - **Crime rate:** Criminal Code offences per 100,000 population, excluding traffic violations.
# - **Clearance rate:** Proportion of reported crimes resolved by police (through charges or otherwise). Clearance ≠ conviction.
# - **Unfounded rate:** Proportion of reported incidents determined to have not occurred or not to constitute a criminal offence.
# - **CAGR:** Compound annual growth rate — the annualized rate of change that normalizes for both time and base rate.
#
# ### Caveats and Limitations
#
# 1. **Police-reported data only.** These statistics reflect crimes reported to and recorded by police. Unreported crime (the "dark figure") is not captured.
#
# 2. **COVID-19 anomaly.** The 2020–2021 period reflects unusual conditions (lockdowns, reduced mobility) that temporarily suppressed some crime categories while potentially increasing others.
#
# 3. **Clearance ≠ conviction.** Clearance rates measure police resolution, not court outcomes. A cleared case may not result in prosecution or conviction.
#
# 4. **Jurisdiction boundaries.** Police jurisdiction boundaries do not always align with municipal boundaries. Some RCMP detachments cover multiple communities.
#
# 5. **Population estimates.** Rates per 100,000 use mid-year population estimates, which are revised after each census.

# %% [markdown]
# ---
#
# *Report generated from StatCan and BC Government open data. All code available in this repository.*
